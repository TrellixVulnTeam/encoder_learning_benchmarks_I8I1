# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import numpy as np

import sys
sys.path.append("..")
from encoder_learning_benchmarks import common, datasets

# %% [markdown]
# # Unbiased, unskewed samples

# %%
dset = datasets.multiplication.manifest.ctor(skewed=False)
xs, ys = dset.sample(1000)

# %%
fig, ax = plt.subplots()
ax.scatter(xs[:, 0], xs[:, 1], c=ys[:, 0])
ax.set_aspect(1)
# Out:
# findfont: Font family ['Stix'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Unbiased, skewed samples

# %%
dset = datasets.multiplication.manifest.ctor(skewed=True)
xs, ys = dset.sample(1000)

# %%
fig, ax = plt.subplots()
ax.scatter(xs[:, 0], xs[:, 1], c=ys[:, 0])
ax.set_aspect(1)

# %% [markdown]
# # Biased, unskewed samples

# %%
dset = datasets.multiplication.manifest.ctor(biased=True)

# %%
xs, ys = dset.sample(10000)
fig, ax = plt.subplots()
ax.plot(xs[:, 0], xs[:, 1])
ax.set_aspect(1)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
# Out:
# (-1.0, 1.0)
