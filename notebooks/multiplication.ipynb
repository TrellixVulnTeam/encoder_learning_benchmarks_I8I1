# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import numpy as np

import sys
sys.path.append("..")
from encoder_learning_benchmarks import common, datasets

# %%
dset = datasets.multiplication.manifest.ctor(skewed=False)
xs, ys = dset.sample(1000)

# %%
fig, ax = plt.subplots()
ax.scatter(xs[:, 0], xs[:, 1], c=ys[:, 0])
ax.set_aspect(1)
